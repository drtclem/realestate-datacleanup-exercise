# %% [markdown]
# # Real Estate Clean up
#
# This is a real dataset, and it was downloaded using web scraping techniques. The data contains registers from **Fotocasa** which is one of the most popular real estate websites in Spain. Please, do not do this (web scraping) unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro, and in no case were economic returns obtained from it.
#
# It contains thousands of data from real houses published on the web www.fotocasa.com. Your goal is to extract as much information as possible with the knowledge you have so far about data science, for example what is the most expensive house in the entire dataset?
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Exercise 00. Read the dataset assets/real_estate.csv and try to visualize the table (★☆☆)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# This CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')

print(ds)
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %%
#Learning more about the dataset
print(ds.columns)
# Out:
# Index(['Unnamed: 0', 'id_realEstates', 'isNew', 'realEstate_name',
#        'phone_realEstate', 'url_inmueble', 'rooms', 'bathrooms', 'surface',
#        'price', 'date', 'description', 'address', 'country', 'level1',
#        'level2', 'level3', 'level4', 'level5', 'level6', 'level7', 'level8',
#        'upperLevel', 'countryId', 'level1Id', 'level2Id', 'level3Id',
#        'level4Id', 'level5Id', 'level6Id', 'level7Id', 'level8Id', 'accuracy',
#        'latitude', 'longitude', 'zipCode', 'customZone'],
#       dtype='object')

# %% [markdown]
# #### Exercise 01. Which is the most expensive house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
#Finding the max price value
max_value = ds['price'].max()

# %%
#printing out the rest of the row where that max price is

row_of_max = ds[ds.isin([max_value]).any(axis=1)]

print(row_of_max)
# Out:
#        Unnamed: 0  id_realEstates  isNew             realEstate_name  \
# 13110       13111       132042636  False  engel volkers torrelodones
#
#        phone_realEstate                                       url_inmueble  \
# 13110       911798512.0  https://www.fotocasa.es/es/comprar/vivienda/vi...
#
#        rooms  bathrooms  surface    price  ... level4Id level5Id level6Id  \
# 13110   19.0        NaN      NaN  8500000  ...        0        0        0
#
#       level7Id level8Id accuracy          latitude          longitude zipCode  \
# 13110        0        0        0  40,5830801751782  -4,12951942848611     NaN
#
#       customZone
# 13110        NaN
#
# [1 rows x 37 columns]

# %%
#just printing out the price and the address for that home
address_max = ds.loc[13110, 'address']

price_max = ds.loc[13110, 'price']

#print(price_max, address_max)

print(f"The house with address {address_max} is the most expensive at {price_max} USD")
# Out:
# The house with address El Escorial is the most expensive at 8500000 USD

# %% [markdown]
# #### Exercise 02. Which is the cheapest house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
#Finding the min price value
min_value = ds['price'].min()

print(min_value)
# Out:
# 0

# %%
#Finding the min price value that isn't zero
min_value_not_zero = ds[ds['price'] !=0]['price'].min()

print(min_value_not_zero)
# Out:
# 600

# %%
#How many places have that min price?

price_is_600 = ds[ds['price']== 600]

print(price_is_600)
# Out:
#       Unnamed: 0  id_realEstates  isNew  realEstate_name  phone_realEstate  \
# 7491        7492       153977752  False  redpiso coslada       910759552.0
#
#                                            url_inmueble  rooms  bathrooms  \
# 7491  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        1.0
#
#       surface  price  ... level4Id level5Id level6Id level7Id level8Id  \
# 7491     80.0    600  ...        0        0        0        0        0
#
#      accuracy  latitude longitude zipCode customZone
# 7491        0  40,41869  -3,54004     NaN        NaN
#
# [1 rows x 37 columns]

# %%
#just printing out the price and the address for that home
address_min = ds.loc[7491, 'address']

price_min = ds.loc[7491, 'price']


print(f"The house with address {address_min} is the cheapest at {price_min} USD")
# Out:
# The house with address Berlin, Coslada is the cheapest at 600 USD

# %% [markdown]
# #### Exercise 03. Which is the biggest and the smallest house in the dataset? (★☆☆)
#
# Print both the address and the surface of the selected houses. For example:
#
# `The biggest house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smallest house is located on County Road 1 N and its surface is 200 meters`

# %%
#Finding the min/max surface size values
min_size = ds['surface'].min()
max_size = ds['surface'].max()

print(min_size)
print(max_size)
# Out:
# 15.0
# 249000.0

# %%
#how many with these respective sizes? 
smallest = ds[ds['surface']== 15.0]
biggest = ds[ds['surface']== 249000.0]

print(smallest)
print(biggest)
# Out:
#      Unnamed: 0  id_realEstates  isNew realEstate_name  phone_realEstate  \
# 498         499       152817874  False        toledo21       910757382.0
#
#                                           url_inmueble  rooms  bathrooms  \
# 498  https://www.fotocasa.es/es/comprar/vivienda/ma...    1.0        1.0
#
#      surface  price  ... level4Id level5Id level6Id level7Id level8Id  \
# 498     15.0  85000  ...        0        0        0        0        0
#
#     accuracy  latitude longitude zipCode customZone
# 498        0  40,40818  -3,70192     NaN        NaN
#
# [1 rows x 37 columns]
#       Unnamed: 0  id_realEstates  isNew          realEstate_name  \
# 6794        6795       153936192  False  habitarium inmobiliaria
#
#       phone_realEstate                                       url_inmueble  \
# 6794       916357732.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#       rooms  bathrooms   surface   price  ... level4Id level5Id level6Id  \
# ...

# %%
#Printing out the address and the size for these homes
address_biggest = ds.loc[6794, 'address']
address_smallest = ds.loc[498, 'address']


print(f"The house with address {address_smallest} is the smallest at {min_size} square meters")
print(f"The house with address {address_biggest} is the largest at {max_size} square meters")
# Out:
# The house with address Calle Amparo,  Madrid Capital is the smallest at 15.0 square meters
# The house with address Sevilla la Nueva is the largest at 249000.0 square meters

# %% [markdown]
# #### Exercise 04. How many populations (level5 column) the dataset contains? (★☆☆)
#
# Print the names of the populations with a comma as a separator. For example:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
population_count = ds['level5'].unique()
#print(population_count)


populations = ", ".join(map(str, population_count))
print(populations)

number_of_populations = len(populations)
print(f'There are {number_of_populations} different populations in the dataset')
# Out:
# Arganda del Rey, Fuenlabrada, Boadilla del Monte, Las Rozas de Madrid,  Madrid Capital, Villaviciosa de Odón, Pinto, Valdemoro, Navalcarnero, Pozuelo de Alarcón, Torrejón de Ardoz, Navalagamella, San Sebastián de los Reyes, Rivas-vaciamadrid, Alpedrete, Móstoles, San Fernando de Henares, Coslada, Becerril de la Sierra, Alcalá de Henares, Chinchón, Parla, Alcorcón, El Escorial, Leganés, Pedrezuela, Majadahonda, Villanueva de la Cañada, Villanueva del Pardillo, Torrelodones, Moralzarzal, Mejorada del Campo, Aranjuez, Corpa, Getafe, Velilla de San Antonio, Sevilla la Nueva, San Martín de la Vega, Villalbilla, Collado Villalba, Alcobendas, El Molar (Madrid), Moraleja de Enmedio, Algete, Campo Real, Torrejón de la Calzada, Colmenar Viejo, Valdemorillo, Fuente El Saz de Jarama, Tres Cantos, Arroyomolinos (Madrid), Griñón, Paracuellos de Jarama, Guadarrama, Titulcia, Galapagar, Collado Mediano, Los Molinos, San Lorenzo de El Escorial, Loeches, San Martín de Valdeiglesias, Navas del Rey, Bus
# ...

# %% [markdown]
# #### Exercise 05. Does the dataset contain NAs? (★☆☆)
#
# Print a boolean value (`True` or `False`) followed by the rows/cols that contains NAs.

# %%
print(ds.isnull().sum())
# Out:
# Unnamed: 0              0
# id_realEstates          0
# isNew                   0
# realEstate_name        10
# phone_realEstate      794
# url_inmueble            0
# rooms                 353
# bathrooms             345
# surface              1250
# price                   0
# date                    0
# description           142
# address                 0
# country                 0
# level1                  0
# level2                  0
# level3                  0
# level4               6643
# level5                  0
# level6              14627
# level7               2277
# level8               8579
# upperLevel              0
# countryId               0
# level1Id                0
# level2Id                0
# level3Id                0
# level4Id                0
# level5Id                0
# level6Id                0
# level7Id                0
# level8Id                0
# accuracy                0
# latitude                0
# longitude               0
# ...

# %% [markdown]
# #### Exercise 06. Delete the NAs of the dataset, if applicable (★★☆)
#
# Print a comparison between the dimensions of the original DataFrame versus the DataFrame after the deletions.

# %%
#going to remove zipcode, customzone, level4, level6, and level8
columns_to_drop = ['customZone', 'zipCode', 'level8', 'level6', 'level4']
#ds = ds.drop(columns = columns_to_drop)

print(ds.shape)
# Out:
# (14071, 37)

# %% [markdown]
# Note, this still leaves some columns with some NAs.

# %% [markdown]
# #### Exercise 07. Which is the mean of prices in the population (level5 column) of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the obtained value.

# %%
ds_arroyo_madrid = ds[ds['level5'] == 'Arroyomolinos (Madrid)']

average_price = ds_arroyo_madrid['price'].mean()

#print(round(average_price, 2))

print(f'The average price of homes in Arroyomolinos is {average_price:.2f} dollars? euros?')
# Out:
# The average price of homes in Arroyomolinos is 296567.91 dollars? euros?

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population (level5 column) of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
ds_arroyo_madrid['price'].plot(kind='hist' , bins = 20, edgecolor='black', title = 'Histogram of Price')

plt.xlabel('Price')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# The histogram above reveals a fairly normal distribution of prices. That is, the most common prices are in closer to the middle of the entire range. However, there are some prices that are less common in the 'middle', this may suggest that pricing trends have specific associations with potential buyers. For example, 250 and 300 may be standard expectations for buyers, leaving values between 250 and 300 less likely to be used. Potentially a tiered expectation or 'slotting' from the market.

# %% [markdown]
# #### Exercise 09. Are the average prices of "Valdemorillo" and "Galapagar" the same? (★★☆)
#
# Print both average prices and then write a conclusion about them.

# %%
ds_valdemorillo = ds[ds['level5'] == 'Valdemorillo']
ds_galapagar = ds[ds['level5']== 'Galapagar']


average_price_vald = ds_valdemorillo['price'].mean()
average_price_gala = ds_galapagar['price'].mean()

print(round(average_price_vald, 2))
print(round(average_price_gala,2))
# Out:
# 371583.02
# 365988.5

# %% [markdown]
# The average price of real estate in Valdemorillo is slightly higher (about 1% higher) than the average price of real estate in Galapagar

# %% [markdown]
# #### Exercise 10. Are the average prices per square meter (price/m2) of "Valdemorillo" and "Galapagar" the same? (★★☆)
#
# Print both average prices and then write a conclusion about it.
#
# Hint: Create a new column called `pps` (price per square meter) and then analyze the values.

# %%
ds_valdemorillo['pps'] = ds_valdemorillo['price'] / ds_valdemorillo['surface']
avg_val_pps = ds_valdemorillo['pps'].mean()
print(avg_val_pps)

ds_galapagar['pps'] = ds_galapagar['price'] / ds_galapagar['surface']
avg_val_gala = ds_galapagar['pps'].mean() 
print(avg_val_gala)
# Out:
# 1317.9502109024984
# 1625.8377911924272
# /tmp/ipykernel_494/3627159227.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds_valdemorillo['pps'] = ds_valdemorillo['price'] / ds_valdemorillo['surface']
# /tmp/ipykernel_494/3627159227.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds_galapagar['pps'] = ds_galapagar['price'] / ds_galapagar['surface']

# %% [markdown]
# The cost of space by square meters is about 20% more in Galapagar as in Valdemorillo.

# %% [markdown]
# #### Exercise 11. Analyze the relation between the surface and the price of the houses (★★☆)
#
# Hint: You can make a `scatter plot`, then write a conclusion about it.

# %%
#making the data for the scatter plot manageable so it will fit nicely
ds = ds[ds['surface'] != 249000.0]
ds = ds[ds['surface'] != 66666.0]
ds = ds[ds['surface'] != 16853.0]
ds = ds[ds['surface'] <=2000]
counts = ds['surface'].value_counts().sort_values(ascending=True)
print(counts)
#counts_surface = ds['surface'].value_counts()
#print(counts_surface)
# Out:
# surface
# 1499.0      1
# 577.0       1
# 836.0       1
# 996.0       1
# 852.0       1
#          ...
# 75.0      204
# 100.0     233
# 70.0      235
# 90.0      240
# 80.0      296
# Name: count, Length: 716, dtype: int64

# %%
#Looking for the best range of values to include in the visual
median_surface = ds['surface'].median()
print(median_surface)

mean_surface = ds['surface'].mean()
print(mean_surface)
#double-checking the maximum value included
max_surface_after = ds['surface'].max()
print(max_surface_after)
# Out:
# 114.0
# 170.94634354345817
# 2000.0

# %%
ds.plot(kind='scatter', x='price', y='surface', title='Graph of Surface Are versus Price')

plt.yticks([0, 250, 500, 750, 1000, 1250, 1500, 1750, 2000])
plt.xlabel('Price per Millions')
plt.ylabel('Surface Area in M^2')

plt.show()

# %%
ds.plot(kind='scatter', x='price', y='surface', title='Graph of Surface Are versus Price')

plt.yticks([0, 250, 500, 750, 1000, 1250, 1500, 1750, 2000])
plt.xlabel('Price per Millions')
plt.ylabel('Surface Area in M^2')
x = ds['price']
y=ds['surface']
m, b = np.polyfit(x,y,1)

#adding a line of best fit
plt.plot(x,m*x+b, color = 'black', label =f'Best Fit Line')

plt.show()

# %% [markdown]
# There is a moderate correlation between surface area and price.

# %% [markdown]
# #### Exercise 12. How many real estate agencies does the dataset contain? (★★☆)
#
# Print the obtained value.

# %%
counts_real_estate = ds['realEstate_name'].value_counts()
print(counts_real_estate)
# Out:
# realEstate_name
# engel volkers madrid    469
# infocasa consulting     300
# housell                 250
# outletdeviviendas       247
# vivienda2               198
#                        ...
# agv inmuebles             1
# mi piso en madrid         1
# europe real estate        1
# isidro paris molano       1
# matibo                    1
# Name: count, Length: 1710, dtype: int64

# %% [markdown]
# There are 1710 real estate agencies listed.

# %% [markdown]
# #### Exercise 13. Which is the population (level5 column) that contains the most houses? (★★☆)
#
# Print both the population and the number of houses.

# %%
population_count = ds['level5'].value_counts()
print(population_count)
# Out:
# level5
#  Madrid Capital               6235
# Alcalá de Henares              499
# Las Rozas de Madrid            373
# Móstoles                       284
# San Sebastián de los Reyes     264
#                               ...
# Fresno de Torote                 1
# Pinilla del Valle                1
# Rascafría                        1
# La Hiruela                       1
# Montejo de la Sierra             1
# Name: count, Length: 167, dtype: int64

# %% [markdown]
# Madrid Capital has the most houses with 6235

# %% [markdown]
# #### Exercise 14. Now let's work with the "south belt" of Madrid. Make a subset of the original DataFrame that contains the following populations (level5 column): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Hint: Filter the original DataFrame using the column `level5` and the function `isin`.

# %%
subset_vals = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']

ds_subset = ds[ds['level5'].isin(subset_vals)]
print(ds_subset)
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# 161           162       153440116  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# 161                                    prolucisa       916350416.0
# ...

# %%
#checking new subset
print(ds_subset['level5'].value_counts())
# Out:
# level5
# Getafe         241
# Fuenlabrada    197
# Leganés        176
# Alcorcón       173
# Name: count, dtype: int64

# %% [markdown]
# #### Exercise 15. Make a bar plot of the median of the prices and explain what you observe (you must use the subset obtained in Exercise 14) (★★★)
#
# Print the bar of the median of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
#Average price for each of the populations
population_subset = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']

mean_prices_subset = ds_subset.groupby('level5')['price'].mean()
                                      
print(round(mean_prices_subset, 2))
# Out:
# level5
# Alcorcón       235453.76
# Fuenlabrada    180955.43
# Getafe         254106.41
# Leganés        210794.38
# Name: price, dtype: float64

# %%
prices_subset = {
    'Alcorcón': 235453.76,
    'Fuenlabrada':    180955.43,
    'Getafe':         254106.41,
    'Leganés':        210794.38
}

locations = list(prices_subset.keys())
prices_subset = list(prices_subset.values())

plt.figure(figsize=(8,6))
plt.bar(locations, prices_subset, color= 'skyblue')

plt.title('Average Prices for Populations', fontsize=14, fontweight='bold')
plt.xlabel('Locations', fontsize=12)
plt.ylabel('Average Price', fontsize=12)

plt.xticks(rotation=45, fontsize=10)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Alcorcón'),
#   Text(1, 0, 'Fuenlabrada'),
#   Text(2, 0, 'Getafe'),
#   Text(3, 0, 'Leganés')])

# %%
#I wanted to do another one for fun- show a sort of inaccurate visual
prices_subset = {
    'Alcorcón': 235453.76,
    'Fuenlabrada':    180955.43,
    'Getafe':         254106.41,
    'Leganés':        210794.38
}

locations = list(prices_subset.keys())
prices_subset = list(prices_subset.values())

plt.figure(figsize=(8,6))
plt.bar(locations, prices_subset, color= 'skyblue')

plt.title('Average Prices for Populations', fontsize=14, fontweight='bold')
plt.xlabel('Locations', fontsize=12)
plt.ylabel('Average Price', fontsize=12)

plt.ylim(150000, 270000)
plt.xticks(rotation=45, fontsize=10)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Alcorcón'),
#   Text(1, 0, 'Fuenlabrada'),
#   Text(2, 0, 'Getafe'),
#   Text(3, 0, 'Leganés')])

# %% [markdown]
# #### The average home price in Fuenlabrada is generally less than the other locations. Getafe and Alcorcón are the most expensive, with Legandés just between those and Fuenlabrada.
#
# #### In the second graph, you can see the differences more clearly (althouh also more misleading)

# %% [markdown]
# #### Exercise 16. Calculate the sample mean and variance of the variables: price, rooms, surface area and bathrooms (you must use the subset obtained in Exercise 14) (★★★)
#
# Print both values for each variable.

# %%
variables = ['price', 'rooms', 'surface', 'bathrooms']

for var in variables:
    mean_value = np.mean(ds_subset[var])
    variance_value = np.var(ds_subset[var], ddof=1)  
    print(f"{var.capitalize()} - Mean: {mean_value}, Variance: {variance_value}")
# Out:
# Price - Mean: 222009.1156289708, Variance: 15166379956.903913
# Rooms - Mean: 3.0063856960408684, Variance: 0.7045627513040866
# Surface - Mean: 111.75222363405337, Variance: 4263.051760316336
# Bathrooms - Mean: 1.6363636363636365, Variance: 0.5727272727272728

# %% [markdown]
# #### Exercise 17. What is the most expensive house in each population? You must use the subset obtained in Exercise 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population.

# %%
#Max price for each of the populations
population_subset = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']

most_expensive_subset = ds_subset.groupby('level5')['price'].max()
                                      
print(most_expensive_subset)
# Out:
# level5
# Alcorcón        950000
# Fuenlabrada     490000
# Getafe         1050000
# Leganés         650000
# Name: price, dtype: int64

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in Exercise 14) (★★★)
#
# For the normalization method, you can use the one you consider; there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot.
#
# Hint: You can help yourself by reviewing the *multihist* demo of Matplotlib.

# %%
#- this has already been defined 
# so this is a reminder
# population_subset = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']
# ds_subset = ds[ds['level5'].isin(subset_vals)]

# Normalize prices for each population
normalized_prices = ds_subset.groupby('level5')['price'].apply(
    lambda x: (x - x.min()) / (x.max() - x.min())
)

# Add normalized values back to ds_subset
ds_subset['Normalized Price'] = normalized_prices.reset_index(drop=True)

hist_data = [
    ds_subset[ds_subset['level5'] == population]['Normalized Price'].values
    for population in population_subset
]

plt.hist(hist_data, bins=10, stacked=False, label=population_subset, alpha=0.7)

# Customize the plot
plt.title('Normalized Price Distributions by Population')
plt.xlabel('Normalized Price')
plt.ylabel('Frequency')
plt.legend(title='Populations')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_494/582857586.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds_subset['Normalized Price'] = normalized_prices.reset_index(drop=True)

# %% [markdown]
# #### As the histogram shows, the normalized prices are low and generally clustered. This suggests that prices are fairly close- especially given the distribution that subtly occurs.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in Exercise 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square meter) and then analyze the values.

# %%
ds_subset['pps']= ds_subset['price']/ ds_subset['surface']

subset_vals_19 = ['Getafe', 'Alcorcón']

ds_subset_19 = ds_subset[ds_subset['level5'].isin(subset_vals_19)]

mean_pps = ds_subset_19.groupby('level5')['pps'].mean()
print(mean_pps)
# Out:
# level5
# Alcorcón    2239.302480
# Getafe      2066.314949
# Name: pps, dtype: float64
# /tmp/ipykernel_494/1336247360.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds_subset['pps']= ds_subset['price']/ ds_subset['surface']

# %% [markdown]
# #### The average price per square meter of homes in Alcorcón are about 8% higher than the homes in Getafe

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph. You must use the subset obtained in Exercise 14 (★★☆)
#
# Hint: Make a scatter plot of each population using subplots.

# %% [markdown]
# ##### This exercise is unclear- which data are you referring to with the plot? I decided to make a bar graph regarding the previous problem (pps)- so comparing the price per square meters of the four different populations.

# %%
ds_subset['pps']= ds_subset['price']/ ds_subset['surface']

mean_pps = ds_subset.groupby('level5')['pps'].mean()
print(mean_pps)
# Out:
# level5
# Alcorcón       2239.302480
# Fuenlabrada    1796.729220
# Getafe         2066.314949
# Leganés        2047.503268
# Name: pps, dtype: float64
# /tmp/ipykernel_494/3052601911.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds_subset['pps']= ds_subset['price']/ ds_subset['surface']

# %%
pps_subset = {
    'Alcorcón':       2239.3,
    'Fuenlabrada':    1796.7,
    'Getafe':         2066.3,
    'Leganés':        2047.5
}

locations = list(pps_subset.keys())
pps_subset = list(pps_subset.values())

plt.figure(figsize=(8,6))
plt.bar(locations, pps_subset, color= 'red')

plt.title('Average Prices per Square Meter', fontsize=14, fontweight='bold')
plt.xlabel('Locations', fontsize=12)
plt.ylabel('Average Price/Square Meter', fontsize=12)

plt.xticks(rotation=45, fontsize=10)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Alcorcón'),
#   Text(1, 0, 'Fuenlabrada'),
#   Text(2, 0, 'Getafe'),
#   Text(3, 0, 'Leganés')])

# %% [markdown]
# #### Exercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in Exercise 14) (★★★★)
#
# Execute the following cell, and then start coding in the next one. You must implement a simple code that transforms the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map

# %%
#Need to change the commas to periods in the long/lad columns. 
#Need to change the datatype to floats for those columns as well
print(ds_subset.shape)

ds_mapping = ds_subset[['level5', 'latitude', 'longitude']]

color_mapping ={
    'Alcorcón': 'green',
    'Fuenlabrada':    'yellow',
    'Getafe':         'blue',
    'Leganés':        'purple'
}

ds_mapping['color code'] = ds_mapping['level5'].map(color_mapping)

ds_mapping['latitude'] = ds_mapping['latitude'].astype(str).str.replace(',', '.').astype(float)
ds_mapping['longitude'] = ds_mapping['longitude'].astype(str).str.replace(',', '.').astype(float)

print(ds_mapping.head)
# Out:
# (787, 38)
# <bound method NDFrame.head of             level5   latitude  longitude color code
# 3      Fuenlabrada  40.285379  -3.795081     yellow
# 85        Alcorcón  40.350590  -3.826930      green
# 94         Leganés  40.319330  -3.775740     purple
# 109       Alcorcón  40.331341  -3.831387      green
# 161    Fuenlabrada  40.274481  -3.791925     yellow
# ...            ...        ...        ...        ...
# 15275  Fuenlabrada  40.313810  -3.837330     yellow
# 15291      Leganés  40.325905  -3.763180     purple
# 15305  Fuenlabrada  40.288219  -3.809862     yellow
# 15322  Fuenlabrada  40.282820  -3.788920     yellow
# 15325  Fuenlabrada  40.280620  -3.798690     yellow
#
# [787 rows x 4 columns]>
# /tmp/ipykernel_494/2350786725.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
from ipyleaflet import Map, CircleMarker

# Verify and clean data
ds_mapping = ds_mapping.dropna(subset=['latitude', 'longitude'])
ds_mapping[['latitude', 'longitude']] = ds_mapping[['latitude', 'longitude']].astype(float)

valid_colors = ['green', 'yellow', 'blue', 'purple']
ds_mapping['color code'] = ds_mapping['color code'].apply(
    lambda x: x if x in valid_colors else 'black'
)

# Initialize the map
map = Map(
    center=(40.32, -3.8),
    zoom=12,
    min_zoom=1,
    max_zoom=20,
    basemap=basemaps.OpenStreetMap.Mapnik
)

# Add CircleMarkers
for _, row in ds_mapping.iterrows():
    marker = CircleMarker(
        location=(row['latitude'], row['longitude']),
        radius=8,
        color=row['color code'],
        fill_color=row['color code'],
        fill_opacity=0.8
    )
    map.add_layer(marker)

# Display the map
map
# Out:
# Map(center=[40.32, -3.8], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_ou…
